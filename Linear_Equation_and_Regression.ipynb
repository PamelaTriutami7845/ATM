# %% [markdown]
# <a href="https://colab.research.google.com/github/PamelaTriutami7845/ATM/blob/main/Linear_Equation_and_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x1=0
x2=0
x3=0
epsilon=0.001
converged=False
x_old=np.array([x1,x2,x3])
print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1,50):
  x1=(10-2*x2-1*x3)/(5)
  x2=(14-2*x1-2*x3)/(6)
  x3=(18-1*x1-2*x2)/(7)
  x=np.array([x1,x2,x3])
  dx=np.sqrt(np.dot(x-x_old,x-x_old))
  print("%d, %.4f, %.4f, %.4f"%(k,x1,x2,x3))
  if dx <epsilon:
    converged=True
    print('Converged!')
    break

  x_old=x
if not converged:
  print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 2.0000, 1.6667, 1.8095
# 2, 0.9714, 1.4063, 2.0308
# 3, 1.0313, 1.3126, 2.0491
# 4, 1.0651, 1.2953, 2.0492
# 5, 1.0721, 1.2929, 2.0489
# 6, 1.0731, 1.2927, 2.0488
# 7, 1.0732, 1.2927, 2.0488
# Converged!

# %%
import numpy as np
x1=0
x2=0
x3=0
epsilon=0.001
converged=False
x_old=np.array([x1,x2,x3])
print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1,50):
  x1=(6-1*x2-2*x3)/(10)
  x2=(25+1*x1-1*x3)/(11)
  x3=(11-2*x1+1*x2)/(10)
  x=np.array([x1,x2,x3])
  dx=np.sqrt(np.dot(x-x_old,x-x_old))
  print("%d, %.4f, %.4f, %.4f"%(k,x1,x2,x3))
  if dx <epsilon:
    converged=True
    print('Converged!')
    break

  x_old=x
if not converged:
  print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 0.6000, 2.3273, 1.2127
# 2, 0.1247, 2.1738, 1.2924
# 3, 0.1241, 2.1665, 1.2918
# 4, 0.1250, 2.1667, 1.2917
# Converged!

# %%
import numpy as np
x1=0
x2=0
x3=0
epsilon=0.001
converged=False
x_old=np.array([x1,x2,x3])
print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1,50):
  x1=(1-2*x2-38*x3)/(1)
  x2=(2-2*x1-10*x3)/(3)
  x3=(3-3*x1-10*x2)/(4)
  x=np.array([x1,x2,x3])
  dx=np.sqrt(np.dot(x-x_old,x-x_old))
  print("%d, %.4f, %.4f, %.4f"%(k,x1,x2,x3))
  if dx <epsilon:
    converged=True
    print('Converged!')
    break

  x_old=x
if not converged:
  print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 1.0000, 0.0000, 0.0000
# 2, 1.0000, 0.0000, 0.0000
# Converged!

# %%
import numpy as np
x1=0
x2=0
x3=0
epsilon=0.001
converged=False
x_old=np.array([x1,x2,x3])
print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1,50):
  x1=(4-10*x2+1*x3)/(2)
  x2=(5-10*x1-2*x3)/(3)
  x3=(6+1*x1-2*x2)/(5)
  x=np.array([x1,x2,x3])
  dx=np.sqrt(np.dot(x-x_old,x-x_old))
  print("%d, %.4f, %.4f, %.4f"%(k,x1,x2,x3))
  if dx <epsilon:
    converged=True
    print('Converged!')
    break

  x_old=x
if not converged:
  print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 2.0000, -5.0000, 3.6000
# 2, 28.8000, -96.7333, 45.6533
# 3, 508.4933, -1723.7467, 792.3973
# 4, 9016.9320, -30583.0382, 14037.8017
# 5, 159936.0920, -542477.1743, 248979.2881
# 6, 2836877.5156, -9622242.9108, 4416273.8674
# 7, 50319353.4877, -170675359.2038, 78334015.5791
# 8, 892543805.8087, -3027368694.7482, 1389456240.2610
# 9, 15831571595.8716, -53698209478.0793, 24645598111.6060
# 10, 280813846448.1996, -952476553566.7360, 437153390717.5343
# 11, 4980959463194.4473, -16894633804458.1797, 7754045414423.3613
# 12, 88350191729504.5938, -299670002707962.5625, 137538039429087.1562
# 13, 1567119033254358.2500, -5315422137133917.0000, 2439592661504439.5000
# 14, 27796907016421804.0000, -94282751829075632.0000, 43272482134914608.0000
# 15, 493050000212835456.0000, -1672348322132727808.0000, 767549328895658240.0000
# 16, 8745516275111468032.0000, -29663420469635330048.0000, 13614471442876426240.0000
# ...
